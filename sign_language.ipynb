# %%
#이미지 부풀리기

import numpy as np
import os

np.random.seed(3)

from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img

# 이미지 크기 조정 비율
optRescale = 1./255
# 이미지 회전 
optRotationRange=90
# 이미지 수평 이동
optWidthShiftRange=0.1
# 이미지 수직 이동
optHeightShiftRange=0.1
# 이미지 밀림 강도 
optShearRange=0.5
# 이미지 확대/ 축소 
optZoomRange=[0.9,2.2]
# 이미지 수평 뒤집기 
optHorizontalFlip = True 
# 이미지 수직 뒤집기 
optVerticalFlip = True
optFillMode='nearest'
# 이미지당 늘리는 갯수 
optNbrOfIncreasePerPic = 5
# 배치 수 
optNbrOfBatchPerPic = 10

'''
 총 개수 optNbrOfIncreasePerPic * optNbrOfBatchPerPic 
 예 >
 사진 1장에 
 optNbrOfIncreasePerPic = 5
 optNbrOfBatchPerPic = 5
 = 1 * 5 * 5 = 25장 생성  
'''

# 데이터셋 불러오기
train_datagen = ImageDataGenerator(rescale=optRescale,
                                   rotation_range=optRotationRange,
                                   width_shift_range=optWidthShiftRange,
                                   height_shift_range=optHeightShiftRange,
                                   shear_range=optShearRange,
                                   zoom_range=optZoomRange,
                                   horizontal_flip=optHorizontalFlip,
                                   vertical_flip=optVerticalFlip,
                                   fill_mode=optFillMode)

a = ['corona', 'prevention', 'do', 'fighting']

for x in a:
    # 원본 이미지 위치 
    optInputPath = 'dataset/'+x
    # 늘릴 이미지가 저장될 위치
    optOutputPath = 'dataset/'
    '''
    폴더가 존재하는지 확인하고
    없다면 생성 
    '''
    def checkFoler(path):
        try:
            if not(os.path.isdir(path)):
                os.makedirs(os.path.join(path))
        except OSError as e:
            if e.errno != errno.EEXIST:                        
                raise            

    def increaseImage(path ,folder):
        for index in range(0,optNbrOfIncreasePerPic):                                   
            img = load_img(path)
            img = img.resize((64,64))
            x = img_to_array(img)
            x = x.reshape((1,) + x.shape)
            i = 0
            # 부풀리는 이미지를 저장할 폴다가 존재하는지 확인
            # 없다면 생성 
            checkFoler(optOutputPath+folder)               
            print('index : ' + str(index))
            for batch in train_datagen.flow(x, batch_size=1, save_to_dir=optOutputPath+folder, save_prefix='new', save_format='jpg'):
                i += 1
                print(folder + " " + str(i))
                if i >= optNbrOfBatchPerPic: 
                    break

    def generator(dirName):
        checkFoler(optOutputPath)
        try:
            fileNames = os.listdir(dirName)
            for fileName in fileNames:
                fullFileName = os.path.join(dirName, fileName)
                if os.path.isdir(fullFileName):                
                    generator(fullFileName)
                else:
                    # 확장자 
                    ext = os.path.splitext(fullFileName)[-1]
                    # 폴더 이름 
                    folderName = os.path.splitext(fullFileName)[0].split('\\')[0].split('/')[1]+'_ex'
                    if(ext == '.jpg'):                    
                        increaseImage(fullFileName, folderName)               
                    
        except PermissionError:
            pass

    if __name__ == "__main__":
        generator(optInputPath)
# Out:
# index : 0
# corona_ex 1
# corona_ex 2
# corona_ex 3
# corona_ex 4
# corona_ex 6
# corona_ex 7
# corona_ex 8
# corona_ex 9
# corona_ex 10
# index : 1
# corona_ex 1
# corona_ex 2
# corona_ex 3
# corona_ex 4
# corona_ex 5
# corona_ex 6
# corona_ex 7
# corona_ex 8
# corona_ex 9
# corona_ex 10
# index : 2
# corona_ex 1
# corona_ex 2
# corona_ex 3
# corona_ex 4
# corona_ex 5
# corona_ex 6
# corona_ex 7
# corona_ex 8
# corona_ex 9
# corona_ex 10
# index : 3
# corona_ex 1
# corona_ex 2
# corona_ex 3
# corona_ex 4
# corona_ex 5
# corona_ex 6
# corona_ex 7
# corona_ex 8
# corona_ex 9
# corona_ex 10
# index : 4
# corona_ex 1
# corona_ex 2
# corona_ex 3
# corona_ex 4
# corona_ex 5
# corona_ex 6
# corona_ex 7
# corona_ex 8
# corona_ex 9
# corona_ex 10
# index : 0
# corona_ex 1
# corona_ex 2
# corona_ex 3
# corona_ex 4
# corona_ex 5
# corona_ex 6
# corona_ex 7
# corona_ex 8
# corona_ex 9
# corona_ex 10
# index : 1
# corona_ex 1
# corona_ex 2
# corona_ex 3
# corona_ex 4
# corona_ex 5
# corona_ex 6
# corona_ex 7
# corona_ex 8
# corona_ex 9
# corona_ex 10
# index : 2
# corona_ex 1
# corona_ex 2
# corona_ex 3
# corona_ex 4
# corona_ex 5
# corona_ex 6
# corona_ex 7
# corona_ex 8
# corona_ex 9
# corona_ex 10
# index : 3
# corona_ex 1
# corona_ex 2
# corona_ex 3
# corona_ex 4
# corona_ex 5
# corona_ex 6
# corona_ex 7
# corona_ex 8
# corona_ex 9
# corona_ex 10
# index : 4
# corona_ex 1
# corona_ex 2
# corona_ex 3
# corona_ex 4
# corona_ex 5
# corona_ex 6
# corona_ex 7
# corona_ex 8
# corona_ex 9
# corona_ex 10
# index : 0
# prevention_ex 1
# prevention_ex 2
# prevention_ex 3
# prevention_ex 4
# prevention_ex 5
# prevention_ex 6
# prevention_ex 7
# prevention_ex 8
# prevention_ex 9
# prevention_ex 10
# index : 1
# prevention_ex 1
# prevention_ex 2
# prevention_ex 3
# prevention_ex 4
# prevention_ex 5
# prevention_ex 6
# prevention_ex 7
# prevention_ex 8
# prevention_ex 9
# prevention_ex 10
# index : 2
# prevention_ex 1
# prevention_ex 2
# prevention_ex 3
# prevention_ex 4
# prevention_ex 5
# prevention_ex 6
# prevention_ex 7
# prevention_ex 8
# prevention_ex 9
# prevention_ex 10
# index : 3
# prevention_ex 1
# prevention_ex 2
# prevention_ex 3
# prevention_ex 4
# prevention_ex 5
# prevention_ex 6
# prevention_ex 7
# prevention_ex 8
# prevention_ex 9
# prevention_ex 10
# index : 4
# prevention_ex 1
# prevention_ex 2
# prevention_ex 3
# prevention_ex 4
# prevention_ex 5
# prevention_ex 6
# prevention_ex 7
# prevention_ex 8
# prevention_ex 9
# prevention_ex 10
# index : 0
# prevention_ex 1
# prevention_ex 2
# prevention_ex 3
# prevention_ex 4
# prevention_ex 5
# prevention_ex 6
# prevention_ex 7
# prevention_ex 8
# prevention_ex 9
# prevention_ex 10
# index : 1
# prevention_ex 1
# prevention_ex 2
# prevention_ex 3
# prevention_ex 4
# prevention_ex 5
# prevention_ex 6
# prevention_ex 7
# prevention_ex 8
# prevention_ex 9
# prevention_ex 10
# index : 2
# prevention_ex 1
# prevention_ex 2
# prevention_ex 3
# prevention_ex 4
# prevention_ex 5
# prevention_ex 6
# prevention_ex 7
# prevention_ex 8
# prevention_ex 9
# prevention_ex 10
# index : 3
# prevention_ex 1
# prevention_ex 2
# prevention_ex 3
# prevention_ex 4
# prevention_ex 5
# prevention_ex 6
# prevention_ex 7
# prevention_ex 8
# prevention_ex 9
# prevention_ex 10
# index : 4
# prevention_ex 1
# prevention_ex 2
# prevention_ex 3
# prevention_ex 4
# prevention_ex 5
# prevention_ex 6
# prevention_ex 7
# prevention_ex 8
# prevention_ex 9
# prevention_ex 10
# index : 0
# prevention_ex 1
# prevention_ex 2
# prevention_ex 3
# prevention_ex 4
# prevention_ex 5
# prevention_ex 6
# prevention_ex 7
# prevention_ex 8
# prevention_ex 9
# prevention_ex 10
# index : 1
# prevention_ex 1
# prevention_ex 2
# prevention_ex 3
# prevention_ex 4
# prevention_ex 5
# prevention_ex 6
# prevention_ex 7
# prevention_ex 8
# prevention_ex 9
# prevention_ex 10
# index : 2
# prevention_ex 1
# prevention_ex 2
# prevention_ex 3
# prevention_ex 4
# prevention_ex 5
# prevention_ex 6
# prevention_ex 7
# prevention_ex 8
# prevention_ex 9
# prevention_ex 10
# index : 3
# prevention_ex 1
# prevention_ex 2
# prevention_ex 3
# prevention_ex 4
# prevention_ex 5
# prevention_ex 6
# prevention_ex 7
# prevention_ex 8
# prevention_ex 9
# prevention_ex 10
# index : 4
# prevention_ex 1
# prevention_ex 2
# prevention_ex 3
# prevention_ex 4
# prevention_ex 5
# prevention_ex 6
# prevention_ex 7
# prevention_ex 8
# prevention_ex 9
# prevention_ex 10
# index : 0
# prevention_ex 1
# prevention_ex 2
# prevention_ex 3
# prevention_ex 4
# prevention_ex 5
# prevention_ex 6
# prevention_ex 7
# prevention_ex 8
# prevention_ex 9
# prevention_ex 10
# index : 1
# prevention_ex 1
# prevention_ex 2
# prevention_ex 3
# prevention_ex 4
# prevention_ex 5
# prevention_ex 6
# prevention_ex 7
# prevention_ex 8
# prevention_ex 9
# prevention_ex 10
# index : 2
# prevention_ex 1
# prevention_ex 2
# prevention_ex 3
# prevention_ex 4
# prevention_ex 5
# prevention_ex 6
# prevention_ex 7
# prevention_ex 8
# prevention_ex 9
# prevention_ex 10
# index : 3
# prevention_ex 1
# prevention_ex 2
# prevention_ex 3
# prevention_ex 4
# prevention_ex 5
# prevention_ex 6
# prevention_ex 7
# prevention_ex 8
# prevention_ex 9
# prevention_ex 10
# index : 4
# prevention_ex 1
# prevention_ex 2
# prevention_ex 3
# prevention_ex 4
# prevention_ex 5
# prevention_ex 6
# prevention_ex 7
# prevention_ex 8
# prevention_ex 9
# prevention_ex 10
# index : 0
# prevention_ex 1
# prevention_ex 2
# prevention_ex 3
# prevention_ex 4
# prevention_ex 5
# prevention_ex 6
# prevention_ex 7
# prevention_ex 8
# prevention_ex 9
# prevention_ex 10
# index : 1
# prevention_ex 1
# prevention_ex 2
# prevention_ex 3
# prevention_ex 4
# prevention_ex 5
# prevention_ex 6
# prevention_ex 7
# prevention_ex 8
# prevention_ex 9
# prevention_ex 10
# index : 2
# prevention_ex 1
# prevention_ex 2
# prevention_ex 3
# prevention_ex 4
# prevention_ex 5
# prevention_ex 6
# prevention_ex 7
# prevention_ex 8
# prevention_ex 9
# prevention_ex 10
# index : 3
# prevention_ex 1
# prevention_ex 2
# prevention_ex 3
# prevention_ex 4
# prevention_ex 5
# prevention_ex 6
# prevention_ex 7
# prevention_ex 8
# prevention_ex 9
# prevention_ex 10
# index : 4
# prevention_ex 1
# prevention_ex 2
# prevention_ex 3
# prevention_ex 4
# prevention_ex 5
# prevention_ex 6
# prevention_ex 7
# prevention_ex 8
# prevention_ex 9
# prevention_ex 10
# index : 0
# do_ex 1
# do_ex 2
# do_ex 3
# do_ex 4
# do_ex 5
# do_ex 6
# do_ex 7
# do_ex 8
# do_ex 9
# do_ex 10
# index : 1
# do_ex 1
# do_ex 2
# do_ex 3
# do_ex 4
# do_ex 5
# do_ex 6
# do_ex 7
# do_ex 8
# do_ex 9
# do_ex 10
# index : 2
# do_ex 1
# do_ex 2
# do_ex 3
# do_ex 4
# do_ex 5
# do_ex 6
# do_ex 7
# do_ex 8
# do_ex 9
# do_ex 10
# index : 3
# do_ex 1
# do_ex 2
# do_ex 3
# do_ex 4
# do_ex 5
# do_ex 6
# do_ex 7
# do_ex 8
# do_ex 9
# do_ex 10
# index : 4
# do_ex 1
# do_ex 2
# do_ex 3
# do_ex 4
# do_ex 5
# do_ex 6
# do_ex 7
# do_ex 8
# do_ex 9
# do_ex 10
# index : 0
# do_ex 1
# do_ex 2
# do_ex 3
# do_ex 4
# do_ex 5
# do_ex 6
# do_ex 7
# do_ex 8
# do_ex 9
# do_ex 10
# index : 1
# do_ex 1
# do_ex 2
# do_ex 3
# do_ex 4
# do_ex 5
# do_ex 6
# do_ex 7
# do_ex 8
# do_ex 9
# do_ex 10
# index : 2
# do_ex 1
# do_ex 2
# do_ex 3
# do_ex 4
# do_ex 5
# do_ex 6
# do_ex 7
# do_ex 8
# do_ex 9
# do_ex 10
# index : 3
# do_ex 1
# do_ex 2
# do_ex 3
# do_ex 4
# do_ex 5
# do_ex 6
# do_ex 7
# do_ex 8
# do_ex 9
# do_ex 10
# index : 4
# do_ex 1
# do_ex 2
# do_ex 3
# do_ex 4
# do_ex 5
# do_ex 6
# do_ex 7
# do_ex 8
# do_ex 9
# do_ex 10
# index : 0
# do_ex 1
# do_ex 2
# do_ex 3
# do_ex 4
# do_ex 5
# do_ex 6
# do_ex 7
# do_ex 8
# do_ex 9
# do_ex 10
# index : 1
# do_ex 1
# do_ex 2
# do_ex 3
# do_ex 4
# do_ex 5
# do_ex 6
# do_ex 7
# do_ex 8
# do_ex 9
# do_ex 10
# index : 2
# do_ex 1
# do_ex 2
# do_ex 3
# do_ex 4
# do_ex 5
# do_ex 6
# do_ex 7
# do_ex 8
# do_ex 9
# do_ex 10
# index : 3
# do_ex 1
# do_ex 2
# do_ex 3
# do_ex 4
# do_ex 5
# do_ex 6
# do_ex 7
# do_ex 8
# do_ex 9
# do_ex 10
# index : 4
# do_ex 1
# do_ex 2
# do_ex 3
# do_ex 4
# do_ex 5
# do_ex 6
# do_ex 7
# do_ex 8
# do_ex 9
# do_ex 10
# index : 0
# do_ex 1
# do_ex 2
# do_ex 3
# do_ex 4
# do_ex 5
# do_ex 6
# do_ex 7
# do_ex 8
# do_ex 9
# do_ex 10
# index : 1
# do_ex 1
# do_ex 2
# do_ex 3
# do_ex 4
# do_ex 5
# do_ex 6
# do_ex 7
# do_ex 8
# do_ex 9
# do_ex 10
# index : 2
# do_ex 1
# do_ex 2
# do_ex 3
# do_ex 4
# do_ex 5
# do_ex 6
# do_ex 7
# do_ex 8
# do_ex 9
# do_ex 10
# index : 3
# do_ex 1
# do_ex 2
# do_ex 3
# do_ex 4
# do_ex 5
# do_ex 6
# do_ex 7
# do_ex 8
# do_ex 9
# do_ex 10
# index : 4
# do_ex 1
# do_ex 2
# do_ex 3
# do_ex 4
# do_ex 5
# do_ex 6
# do_ex 7
# do_ex 8
# do_ex 9
# do_ex 10
# index : 0
# do_ex 1
# do_ex 2
# do_ex 3
# do_ex 4
# do_ex 5
# do_ex 6
# do_ex 7
# do_ex 8
# do_ex 9
# do_ex 10
# index : 1
# do_ex 1
# do_ex 2
# do_ex 3
# do_ex 4
# do_ex 5
# do_ex 6
# do_ex 7
# do_ex 8
# do_ex 9
# do_ex 10
# index : 2
# do_ex 1
# do_ex 2
# do_ex 3
# do_ex 4
# do_ex 5
# do_ex 6
# do_ex 7
# do_ex 8
# do_ex 9
# do_ex 10
# index : 3
# do_ex 1
# do_ex 2
# do_ex 3
# do_ex 4
# do_ex 5
# do_ex 6
# do_ex 7
# do_ex 8
# do_ex 9
# do_ex 10
# index : 4
# do_ex 1
# do_ex 2
# do_ex 3
# do_ex 4
# do_ex 5
# do_ex 6
# do_ex 7
# do_ex 8
# do_ex 9
# do_ex 10
# index : 0
# fighting_ex 1
# fighting_ex 2
# fighting_ex 3
# fighting_ex 4
# fighting_ex 5
# fighting_ex 6
# fighting_ex 7
# fighting_ex 4
# fighting_ex 5
# fighting_ex 6
# fighting_ex 7
# fighting_ex 8
# fighting_ex 9
# fighting_ex 10
# index : 0
# fighting_ex 1
# fighting_ex 2
# fighting_ex 3
# fighting_ex 4
# fighting_ex 5
# fighting_ex 6
# fighting_ex 7
# fighting_ex 8
# fighting_ex 9
# fighting_ex 10
# index : 1
# fighting_ex 1
# fighting_ex 2
# fighting_ex 3
# fighting_ex 4
# fighting_ex 5
# fighting_ex 6
# fighting_ex 7
# fighting_ex 8
# fighting_ex 9
# fighting_ex 10
# index : 2
# fighting_ex 1
# fighting_ex 2
# fighting_ex 3
# fighting_ex 4
# fighting_ex 5
# fighting_ex 6
# fighting_ex 7
# fighting_ex 8
# fighting_ex 9
# fighting_ex 10
# index : 3
# fighting_ex 1
# fighting_ex 2
# fighting_ex 3
# fighting_ex 4
# fighting_ex 5
# fighting_ex 6
# fighting_ex 7
# fighting_ex 8
# fighting_ex 9
# fighting_ex 10
# index : 4
# fighting_ex 1
# fighting_ex 2
# fighting_ex 3
# fighting_ex 4
# fighting_ex 5
# fighting_ex 6
# fighting_ex 7
# fighting_ex 8
# fighting_ex 9
# fighting_ex 10
# index : 0
# fighting_ex 1
# fighting_ex 2
# fighting_ex 3
# fighting_ex 4
# fighting_ex 5
# fighting_ex 6
# fighting_ex 7
# fighting_ex 8
# fighting_ex 9
# fighting_ex 10
# index : 1
# fighting_ex 1
# fighting_ex 2
# fighting_ex 3
# fighting_ex 4
# fighting_ex 5
# fighting_ex 6
# fighting_ex 7
# fighting_ex 8
# fighting_ex 9
# fighting_ex 10
# index : 2
# fighting_ex 1
# fighting_ex 2
# fighting_ex 3
# fighting_ex 4
# fighting_ex 5
# fighting_ex 6
# fighting_ex 7
# fighting_ex 8
# fighting_ex 9
# fighting_ex 10
# index : 3
# fighting_ex 1
# fighting_ex 2
# fighting_ex 3
# fighting_ex 4
# fighting_ex 5
# fighting_ex 6
# fighting_ex 7
# fighting_ex 8
# fighting_ex 9
# fighting_ex 10
# index : 4
# fighting_ex 1
# fighting_ex 2
# fighting_ex 3
# fighting_ex 4
# fighting_ex 5
# fighting_ex 6
# fighting_ex 7
# fighting_ex 8
# fighting_ex 9
# fighting_ex 10

# %%
#이미지 전처리

import cv2
import os
import numpy as np
from PIL import Image  

b = ['corona_ex', 'prevention_ex', 'do_ex', 'fighting_ex']

for y in b:
    path = 'dataset/'+y
    imagePaths = [os.path.join(path,file_name) for file_name in os.listdir(path)]
    for imagePath in imagePaths:
        img=Image.open(imagePath).convert('L')
        img_numpy=np.array(img,'uint8')
        cv2.imwrite(imagePath, img_numpy)
        border01, binary01 = cv2.threshold(img_numpy, 150, 255, cv2.THRESH_BINARY)
        img90 = cv2.rotate(binary01, cv2.ROTATE_90_CLOCKWISE)
        cv2.imwrite(imagePath, img90)
        print("all done")
# Out:
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# all done
